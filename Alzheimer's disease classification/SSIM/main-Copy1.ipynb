# %%
from skimage.measure import compare_ssim
import argparse
import imutils
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %%
target = r'./target image/ADNI_021_S_0642_MR_Axial_PD_T2_FSE__br_raw_20070719074303183_60_S35278_I60826.png'
imageA = cv2.imread(target, cv2.IMREAD_GRAYSCALE)

Dir = r'/home/trojan/Desktop/dimentia/dataset/data_2categ/data/train/AD/'
#Dir = r'./test images bad/'
SSIM = []

for image in glob.glob(Dir + '*.png'):
    imageB = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
    croppedA = imageA[60:190, 80:180]
    croppedB = imageB[60:190, 80:180] 
    (score, diff) = compare_ssim(croppedA, croppedB, full=True)
    diff = (diff * 255).astype("uint8")
    SSIM.append(score)
# Out:
# /home/trojan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   if sys.path[0] == '':

# %%
print(len(SSIM))
# Out:
# 406

# %%
print(min(SSIM))
# Out:
# 0.06664877373500853

# %%
print(max(SSIM))
# Out:
# 1.0

# %%
print(SSIM)
# Out:
# [0.10757618481391645, 0.12361510788423445, 0.13696791878171272, 0.10867304910269912, 0.14207769938954581, 0.11259898736664946, 0.18900008482186745, 0.16999944623127572, 0.12320769549127598, 0.13943320333947493, 0.12435921613472198, 0.14635157953070024, 0.14470861166821525, 0.14292342728448226, 0.10816187849106398, 0.15610033228028952, 0.1776006341233303, 0.11011778680134271, 0.1425233968736395, 0.14660954953311334, 0.1514890686361855, 0.16845553888608333, 0.13744908252563653, 0.19610864492873176, 0.12517907404489917, 0.14806493926788744, 0.1083790763257981, 0.128711899190664, 0.11094356127445973, 0.12495164757506555, 0.14174902489880045, 0.10683674276004565, 0.11193409522787574, 0.17614516866637964, 0.17006709329147854, 0.13513157640232107, 0.1474425908734072, 0.12776968112669568, 0.08923255707325417, 0.1997540648937653, 0.1360234445269426, 0.12627529187667252, 0.11604440981203189, 0.1136332650056947, 0.12210882610613273, 0.15365309489681542, 0.1659615799735001, 0.14323976567039728, 0.11149547572179358, 0.1343914384722329, 0.14399138832656733, 0.13480870864169348, 0.10536521198335165, 0.18179543978501697, 0.18748075959764238, 0.18761602878305778, 0.12210346449713853, 0.0959821668095301, 0.15633472544843943, 0.15445830306179478, 0.15712214367748994, 0.13886293774632164, 0.14321400990598998, 0.17123071427316197, 0.12568533222971134, 0.13586585410298507, 0.20619626902847146, 0.10643733744890221, 0.12090250084085674, 0.1551647258494727, 0.11853567317149992, 0.1