# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

Dir = r"/home/trojan/Desktop/dimentia/data_10slices/dataset with PGGAN/train/AD"
for images in os.listdir(Dir):
    img = cv2.imread(os.path.join(Dir,images), cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(img, 50, 150)

    #fig = plt.figure(figsize=(20,20))
    #plt.subplot(121),plt.imshow(img,cmap = 'gray')
    #plt.title('Original Image'), plt.xticks([]), plt.yticks([])
    #plt.plot(122),
    plt.imshow(edges, cmap = 'gray')
    #plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

    plt.show()
    #fig.savefig(('canny with mean filter.png'))
    break
