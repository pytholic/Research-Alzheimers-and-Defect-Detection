# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras import layers
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import numpy as np
import losses
import time
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

# %%
dataDir = r"/home/trojan/Desktop/dimentia/data_10slices/dataset with PGGAN/train"

IMG_SHAPE = 256
num_classes = 2
BS = 16
encoder_epochs = 50
classifier_epochs = 50
AUTO = tf.data.experimental.AUTOTUNE
dropout_rate = 0.2

# %%
def lr_schedule(epoch):

    lr = 1e-5 
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 40: # 120
        lr *= 1e-2
    elif epoch > 20: #80
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  dataDir,
  validation_split=0.2,
  subset="training",
  seed=42,
  image_size=(IMG_SHAPE, IMG_SHAPE),
  batch_size=BS,
  shuffle=True)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  dataDir,
  validation_split=0.2,
  subset="validation",
  seed=42,
  image_size=(IMG_SHAPE, IMG_SHAPE),
  batch_size=BS,
  shuffle=True)
# Out:
# Found 19677 files belonging to 2 classes.
# Using 15742 files for training.
# Found 19677 files belonging to 2 classes.
# Using 3935 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['AD', 'CN']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 256, 256, 3)
# (16,)

# %%
# Data Pipeline

@tf.function
def preprocess_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (IMG_SHAPE, IMG_SHAPE))
    image = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(image)
    return (image, label)

train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .prefetch(AUTO)
)


validation_ds = (
    val_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
# Model Bulding

# Reference: https://github.com/wangz10/contrastive_loss/blob/master/model.py
class UnitNormLayer(tf.keras.layers.Layer):
    '''Normalize vectors (euclidean norm) in batch to unit hypersphere.
    '''
    def __init__(self, **kwargs):
        super(UnitNormLayer, self).__init__()

    def call(self, input_tensor):
        norm = tf.norm(input_tensor, axis=1)
        return input_tensor / tf.reshape(norm, [-1, 1])

# %%
normalization_layer = UnitNormLayer()
inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))

# %%
cnn_top = Conv2D(16, (7,7), padding='same', activation='relu')(inputs)
cnn_top = BatchNormalization()(cnn_top)
cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = Conv2D(32, (5,5), padding='same', activation='relu')(cnn_top)
cnn_top = BatchNormalization()(cnn_top)
cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = Conv2D(64, (3,3), padding='same', activation='relu')(cnn_top)
cnn_top = BatchNormalization()(cnn_top)
cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = Conv2D(128, (3,3), padding='same', activation='relu')(cnn_top)
cnn_top = BatchNormalization()(cnn_top)
cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = Conv2D(256, (3,3), padding='same', activation='relu')(cnn_top)
cnn_top = BatchNormalization()(cnn_top)
cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = Conv2D(512, (3,3), padding='same', activation='relu',)(cnn_top)
cnn_top = BatchNormalization()(cnn_top)
#cnn_top = MaxPooling2D(pool_size=(2, 2))(cnn_top)
cnn_top = GlobalAveragePooling2D()(cnn_top)
cnn_top = Flatten()(cnn_top)
cnn_top = Dense(256)(cnn_top)

resized_mid = tf.keras.layers.experimental.preprocessing.Resizing(128, 128, interpolation='bilinear')(inputs)
cnn_mid = Conv2D(16, (7,7), padding='same', activation='relu')(resized_mid)
cnn_mid = BatchNormalization()(cnn_mid)
cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = Conv2D(32, (5,5), padding='same', activation='relu')(cnn_mid)
cnn_mid = BatchNormalization()(cnn_mid)
cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = Conv2D(64, (3,3), padding='same', activation='relu')(cnn_mid)
cnn_mid = BatchNormalization()(cnn_mid)
cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = Conv2D(128, (3,3), padding='same', activation='relu')(cnn_mid)
cnn_mid = BatchNormalization()(cnn_mid)
cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = Conv2D(256, (3,3), padding='same', activation='relu')(cnn_mid)
cnn_mid = BatchNormalization()(cnn_mid)
cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = Conv2D(512, (3,3), padding='same', activation='relu')(cnn_mid)
cnn_mid = BatchNormalization()(cnn_mid)
#cnn_mid = MaxPooling2D(pool_size=(2, 2))(cnn_mid)
cnn_mid = GlobalAveragePooling2D()(cnn_mid)
cnn_mid = Flatten()(cnn_mid)
cnn_mid = Dense(256)(cnn_mid)


resized_bot = tf.keras.layers.experimental.preprocessing.Resizing(64, 64, interpolation='bilinear')(inputs)
cnn_bot = Conv2D(16, (7,7), padding='same', activation='relu')(resized_bot)
cnn_bot = BatchNormalization()(cnn_bot)
cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = Conv2D(32, (5,5), padding='same', activation='relu')(cnn_bot)
cnn_bot = BatchNormalization()(cnn_bot)
cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = Conv2D(64, (3,3), padding='same', activation='relu')(cnn_bot)
cnn_bot = BatchNormalization()(cnn_bot)
cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = Conv2D(128, (3,3), padding='same', activation='relu')(cnn_bot)
cnn_bot = BatchNormalization()(cnn_bot)
cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = Conv2D(256, (3,3), padding='same', activation='relu')(cnn_bot)
cnn_bot = BatchNormalization()(cnn_bot)
cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = Conv2D(512, (3,3), padding='same', activation='relu')(cnn_bot)
cnn_bot = BatchNormalization()(cnn_bot)
#cnn_bot = MaxPooling2D(pool_size=(2, 2))(cnn_bot)
cnn_bot = GlobalAveragePooling2D()(cnn_bot)
cnn_bot = Flatten()(cnn_bot)
cnn_bot = Dense(256)(cnn_bot)

# %%
merged_model = concatenate([cnn_top, cnn_mid, cnn_bot])

final_model = Model(inputs, merged_model)

# %%
tf.keras.utils.plot_model(final_model, show_shapes=True)

# %%
# Encoder Network
def encoder_net():
    inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
    normalization_layer = UnitNormLayer()

    encoder = final_model
    encoder.trainable = True

    embeddings = encoder(inputs, training=True)
    #embeddings = GlobalAveragePooling2D()(embeddings)
    #norm_embeddings = normalization_layer(embeddings)

    encoder_network = Model(inputs, embeddings)

    return encoder_network

# Projector Network
def projector_net():
    projector = tf.keras.models.Sequential([
        Dense(256, activation="relu"),
        UnitNormLayer()
])

    return projector

# %%
encoder_r = encoder_net()
projector_z = projector_net()

# %%
tf.keras.utils.plot_model(encoder_r, show_shapes=True)

# %%
#Training encoder and thed projector

optimizer = tf.keras.optimizers.Adam(lr=lr_schedule(0))

encoder_r = encoder_net()
projector_z = projector_net()

@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        r = encoder_r(images, training=True)
        z = projector_z(r, training=True)
        loss = losses.max_margin_contrastive_loss(z, labels)

    gradients = tape.gradient(loss, 
        encoder_r.trainable_variables + projector_z.trainable_variables)
    optimizer.apply_gradients(zip(gradients, 
        encoder_r.trainable_variables + projector_z.trainable_variables))

    return loss
# Out:
# Learning rate:  1e-05

# %%
EPOCHS = encoder_epochs
train_loss_results = []

epoch_time = 0
total_time = 0
for epoch in range(EPOCHS):
    start = time.time()
    epoch_loss_avg = tf.keras.metrics.Mean()

    for (images, labels) in train_ds:
        loss = train_step(images, labels)
        epoch_loss_avg.update_state(loss) 

    train_loss_results.append(epoch_loss_avg.result())
    
    print("Epoch: {} Loss: {:.3f}".format(epoch, epoch_loss_avg.result()))

    end = time.time()
    epoch_time = end - start
    total_time += epoch_time
    
    print(f"Epoch Time: {epoch_time}")
    print(f"Total Time: {total_time}")
    
with plt.xkcd():
    plt.plot(train_loss_results)
    plt.title("Supervised Contrastive Loss")
    plt.show()
# Out:
# Epoch: 0 Loss: 0.651
# Epoch Time: 37.11034393310547
# Total Time: 37.11034393310547
# Epoch: 1 Loss: 0.450
# Epoch Time: 33.661267042160034
# Total Time: 70.7716109752655
# Epoch: 2 Loss: 0.312
# Epoch Time: 33.18151044845581
# Total Time: 103.95312142372131
# Epoch: 3 Loss: 0.203
# Epoch Time: 33.04199481010437
# Total Time: 136.99511623382568
# Epoch: 4 Loss: 0.155
# Epoch Time: 33.19976186752319
# Total Time: 170.19487810134888
# Epoch: 5 Loss: 0.121
# Epoch Time: 33.12583875656128
# Total Time: 203.32071685791016
# Epoch: 6 Loss: 0.092
# Epoch Time: 33.1615686416626
# Total Time: 236.48228549957275
# Epoch: 7 Loss: 0.069
# Epoch Time: 33.229536056518555
# Total Time: 269.7118215560913
# Epoch: 8 Loss: 0.052
# Epoch Time: 33.22584867477417
# Total Time: 302.9376702308655
# Epoch: 9 Loss: 0.039
# Epoch Time: 33.211825132369995
# Total Time: 336.1494953632355
# Epoch: 10 Loss: 0.031
# Epoch Time: 33.24820876121521
# Total Time: 369.3977041244507
# Epoch: 11 Loss: 0.024
# Epoch Time: 33.20637249946594
# Total Time: 402.6040766239166
# Epoch: 12 Loss: 0.021
# Epoch Time: 33.182265281677246
# Total Time: 435.7863419055939
# Epoch: 13 Loss: 0.018
# Epoch Time: 33.215309858322144
# Total Time: 469.001651763916
# Epoch: 14 Loss: 0.016
# Epoch Time: 33.034984827041626
# Total Time: 502.03663659095764
# Epoch: 15 Loss: 0.013
# Epoch Time: 33.11191940307617
# Total Time: 535.1485559940338
# Epoch: 16 Loss: 0.014
# Epoch Time: 33.25445747375488
# Total Time: 568.4030134677887
# Epoch: 17 Loss: 0.012
# Epoch Time: 33.23388981819153
# Total Time: 601.6369032859802
# Epoch: 18 Loss: 0.011
# Epoch Time: 32.98949956893921
# Total Time: 634.6264028549194
# Epoch: 19 Loss: 0.010
# Epoch Time: 33.20256853103638
# Total Time: 667.8289713859558
# Epoch: 20 Loss: 0.010
# Epoch Time: 33.216702938079834
# Total Time: 701.0456743240356
# Epoch: 21 Loss: 0.009
# Epoch Time: 33.006330251693726
# Total Time: 734.0520045757294
# Epoch: 22 Loss: 0.009
# Epoch Time: 33.17986536026001
# Total Time: 767.2318699359894
# Epoch: 23 Loss: 0.009
# Epoch Time: 33.20549011230469
# Total Time: 800.4373600482941
# Epoch: 24 Loss: 0.009
# Epoch Time: 33.22809314727783
# Total Time: 833.6654531955719
# Epoch: 25 Loss: 0.007
# Epoch Time: 33.14504051208496
# Total Time: 866.8104937076569
# Epoch: 26 Loss: 0.007
# Epoch Time: 33.2188766002655
# Total Time: 900.0293703079224
# Epoch: 27 Loss: 0.007
# Epoch Time: 33.271796226501465
# Total Time: 933.3011665344238
# Epoch: 28 Loss: 0.008
# Epoch Time: 33.27679252624512
# Total Time: 966.577959060669
# Epoch: 29 Loss: 0.008
# Epoch Time: 33.21653890609741
# Total Time: 999.7944979667664
# Epoch: 30 Loss: 0.007
# Epoch Time: 33.16029906272888
# Total Time: 1032.9547970294952
# Epoch: 31 Loss: 0.007
# Epoch Time: 33.313289642333984
# Total Time: 1066.2680866718292
# Epoch: 32 Loss: 0.007
# Epoch Time: 33.14244508743286
# Total Time: 1099.410531759262
# Epoch: 33 Loss: 0.007
# Epoch Time: 33.33191752433777
# Total Time: 1132.7424492835999
# Epoch: 34 Loss: 0.007
# Epoch Time: 33.20426654815674
# Total Time: 1165.9467158317566
# Epoch: 35 Loss: 0.007
# Epoch Time: 33.103261947631836
# Total Time: 1199.0499777793884
# Epoch: 36 Loss: 0.006
# Epoch Time: 33.246318340301514
# Total Time: 1232.29629611969
# Epoch: 37 Loss: 0.006
# Epoch Time: 33.067851305007935
# Total Time: 1265.3641474246979
# Epoch: 38 Loss: 0.008
# Epoch Time: 33.1207172870636
# Total Time: 1298.4848647117615
# Epoch: 39 Loss: 0.006
# Epoch Time: 33.29633831977844
# Total Time: 1331.78120303154
# Epoch: 40 Loss: 0.006
# Epoch Time: 33.0867178440094
# Total Time: 1364.8679208755493
# Epoch: 41 Loss: 0.007
# Epoch Time: 33.17255425453186
# Total Time: 1398.0404751300812
# Epoch: 42 Loss: 0.007
# Epoch Time: 33.08622670173645
# Total Time: 1431.1267018318176
# Epoch: 43 Loss: 0.006
# Epoch Time: 33.23296809196472
# Total Time: 1464.3596699237823
# Epoch: 44 Loss: 0.006
# Epoch Time: 33.12838006019592
# Total Time: 1497.4880499839783
# Epoch: 45 Loss: 0.006
# Epoch Time: 33.25519156455994
# Total Time: 1530.7432415485382
# Epoch: 46 Loss: 0.007
# Epoch Time: 33.163535356521606
# Total Time: 1563.9067769050598
# Epoch: 47 Loss: 0.006
# Epoch Time: 33.1787211894989
# Total Time: 1597.0854980945587
# Epoch: 48 Loss: 0.004
# Epoch Time: 33.21269083023071
# Total Time: 1630.2981889247894
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# Epoch: 49 Loss: 0.008
# Epoch Time: 33.261048793792725
# Total Time: 1663.5592377185822

# %%
encoder_r.save('encoder_model.h5')
projector_z.save('projection_model.h5')

# %%
encoder_r = load_model('encoder_model.h5', custom_objects={'UnitNormLayer': UnitNormLayer}, compile=False)

# %%
# Supervised training

def supervised_model():
    inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
    encoder_r.trainable = False

    r = encoder_r(inputs, training=False)
    r = layers.Dense(256, activation="relu")(r)
    r = layers.Dropout(dropout_rate)(r)
    r = layers.Dense(128, activation="relu")(r)
    r = layers.Dropout(dropout_rate)(r)
    outputs = Dense(num_classes)(r)

    supervised_model = Model(inputs, outputs)

    return supervised_model

# %%
supervised_classifier = supervised_model()

supervised_classifier.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_schedule(0)),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])


checkpoint = ModelCheckpoint('best_model_contrastive.h5', monitor='val_sparse_categorical_accuracy', mode='max', verbose=1, save_best_only=True)
#es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5,
    #restore_best_weights=True, verbose=2)

lr_scheduler = LearningRateScheduler(lr_schedule)
    
supervised_classifier.fit(train_ds,
    validation_data=validation_ds,
    epochs=classifier_epochs,
    callbacks=[checkpoint, lr_scheduler])
# Out:
# Learning rate:  1e-05
# Learning rate:  1e-05
# Epoch 1/50
# 981/984 [============================>.] - ETA: 0s - loss: 0.1734 - sparse_categorical_accuracy: 0.9718
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.92706, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 42s 42ms/step - loss: 0.1729 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.1790 - val_sparse_categorical_accuracy: 0.9271
# Learning rate:  1e-05
# Epoch 2/50
# 980/984 [============================>.] - ETA: 0s - loss: 0.0139 - sparse_categorical_accuracy: 0.9999
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.92706 to 0.93138, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.1782 - val_sparse_categorical_accuracy: 0.9314
# Learning rate:  1e-05
# Epoch 3/50
# 982/984 [============================>.] - ETA: 0s - loss: 0.0044 - sparse_categorical_accuracy: 0.9999
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.93138 to 0.93164, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9316
# Learning rate:  1e-05
# Epoch 4/50
# 981/984 [============================>.] - ETA: 0s - loss: 0.0020 - sparse_categorical_accuracy: 0.9999
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.93164 to 0.93266, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.2031 - val_sparse_categorical_accuracy: 0.9327
# Learning rate:  1e-05
# Epoch 5/50
# 980/984 [============================>.] - ETA: 0s - loss: 0.0011 - sparse_categorical_accuracy: 0.9999
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.93266
# 984/984 [==============================] - 41s 42ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.2170 - val_sparse_categorical_accuracy: 0.9321
# Learning rate:  1e-05
# Epoch 6/50
# 981/984 [============================>.] - ETA: 0s - loss: 5.8289e-04 - sparse_categorical_accuracy: 0.9999- ETA: 2s - loss: 5.9882e-04 - sparse
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.93266 to 0.93316, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 5.8179e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.2309 - val_sparse_categorical_accuracy: 0.9332
# Learning rate:  1e-05
# Epoch 7/50
# 980/984 [============================>.] - ETA: 0s - loss: 4.0613e-04 - sparse_categorical_accuracy: 0.9999
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 4.0557e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.2444 - val_sparse_categorical_accuracy: 0.9327
# Learning rate:  1e-05
# Epoch 8/50
# 983/984 [============================>.] - ETA: 0s - loss: 2.5332e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 2.5313e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2581 - val_sparse_categorical_accuracy: 0.9324
# Learning rate:  1e-05
# Epoch 9/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.6161e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 1.6121e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2699 - val_sparse_categorical_accuracy: 0.9316
# Learning rate:  1e-05
# Epoch 10/50
# 980/984 [============================>.] - ETA: 0s - loss: 9.4441e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 9.4124e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2826 - val_sparse_categorical_accuracy: 0.9319
# Learning rate:  1e-05
# Epoch 11/50
# 982/984 [============================>.] - ETA: 0s - loss: 6.1991e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 6.1901e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2969 - val_sparse_categorical_accuracy: 0.9321
# Learning rate:  1e-05
# Epoch 12/50
# 981/984 [============================>.] - ETA: 0s - loss: 6.6243e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 6.6082e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3085 - val_sparse_categorical_accuracy: 0.9319
# Learning rate:  1e-05
# Epoch 13/50
# 980/984 [============================>.] - ETA: 0s - loss: 2.5037e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 2.4982e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3199 - val_sparse_categorical_accuracy: 0.9321
# Learning rate:  1e-05
# Epoch 14/50
# 982/984 [============================>.] - ETA: 0s - loss: 2.1190e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.93316
# 984/984 [==============================] - 41s 42ms/step - loss: 2.1153e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3328 - val_sparse_categorical_accuracy: 0.9329
# Learning rate:  1e-05
# Epoch 15/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.1924e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.93316 to 0.93367, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 1.1883e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.9337
# Learning rate:  1e-05
# Epoch 16/50
# 980/984 [============================>.] - ETA: 0s - loss: 9.3863e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.93367 to 0.93418, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 9.3524e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3597 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1e-05
# Epoch 17/50
# 982/984 [============================>.] - ETA: 0s - loss: 2.1715e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 2.1676e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3729 - val_sparse_categorical_accuracy: 0.9334
# Learning rate:  1e-05
# Epoch 18/50
# 980/984 [============================>.] - ETA: 0s - loss: 4.6760e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 4.6593e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3816 - val_sparse_categorical_accuracy: 0.9332
# Learning rate:  1e-05
# Epoch 19/50
# 982/984 [============================>.] - ETA: 0s - loss: 3.9558e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 3.9673e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3914 - val_sparse_categorical_accuracy: 0.9332
# Learning rate:  1e-05
# Epoch 20/50
# 980/984 [============================>.] - ETA: 0s - loss: 4.9090e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 4.8923e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4030 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1e-05
# Epoch 21/50
# 980/984 [============================>.] - ETA: 0s - loss: 3.6151e-06 - sparse_categorical_accuracy: 1.0000- ETA: 3s - loss: 3.8
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 3.6017e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4143 - val_sparse_categorical_accuracy: 0.9334
# Learning rate:  1.0000000000000002e-06
# Epoch 22/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.9040e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.9006e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.9332
# Learning rate:  1.0000000000000002e-06
# Epoch 23/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.7069e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.7016e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4165 - val_sparse_categorical_accuracy: 0.9334
# Learning rate:  1.0000000000000002e-06
# Epoch 24/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.8125e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 41ms/step - loss: 1.8672e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4181 - val_sparse_categorical_accuracy: 0.9334
# Learning rate:  1.0000000000000002e-06
# Epoch 25/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.8777e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.8742e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4199 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 26/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.3922e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.3876e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4219 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 27/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.1757e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.1742e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4242 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 28/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.3099e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.3051e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4267 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 29/50
# 981/984 [============================>.] - ETA: 0s - loss: 1.1271e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.1254e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4294 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 30/50
# 981/984 [============================>.] - ETA: 0s - loss: 1.2080e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.2048e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4314 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 31/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.5061e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.5034e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4342 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 32/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.0021e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 9.9869e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4362 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 33/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.2616e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.93418
# 984/984 [==============================] - 41s 42ms/step - loss: 1.2592e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4378 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 34/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.1930e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00034: val_sparse_categorical_accuracy improved from 0.93418 to 0.93443, saving model to best_model_contrastive.h5
# 984/984 [==============================] - 41s 42ms/step - loss: 1.1887e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4398 - val_sparse_categorical_accuracy: 0.9344
# Learning rate:  1.0000000000000002e-06
# Epoch 35/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.5320e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 1.5266e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4422 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 36/50
# 980/984 [============================>.] - ETA: 0s - loss: 1.0779e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 1.0738e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4441 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000002e-06
# Epoch 37/50
# 982/984 [============================>.] - ETA: 0s - loss: 6.6051e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 6.5951e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4458 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 38/50
# 980/984 [============================>.] - ETA: 0s - loss: 8.3460e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 8.3533e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4476 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 39/50
# 983/984 [============================>.] - ETA: 0s - loss: 9.0515e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 9.0440e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4499 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 40/50
# 980/984 [============================>.] - ETA: 0s - loss: 6.7873e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 6.7645e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4518 - val_sparse_categorical_accuracy: 0.9342
# Learning rate:  1.0000000000000002e-06
# Epoch 41/50
# 982/984 [============================>.] - ETA: 0s - loss: 7.9492e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 7.9346e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4539 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 42/50
# 982/984 [============================>.] - ETA: 0s - loss: 9.2345e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 9.2208e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4541 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 43/50
# 982/984 [============================>.] - ETA: 0s - loss: 5.0689e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 41ms/step - loss: 5.0597e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4542 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 44/50
# 980/984 [============================>.] - ETA: 0s - loss: 7.5401e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 7.5168e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4543 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 45/50
# 982/984 [============================>.] - ETA: 0s - loss: 8.0340e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 8.0194e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4545 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 46/50
# 982/984 [============================>.] - ETA: 0s - loss: 6.7532e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 6.7410e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4546 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 47/50
# 981/984 [============================>.] - ETA: 0s - loss: 5.4884e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 5.4735e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4548 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 48/50
# 982/984 [============================>.] - ETA: 0s - loss: 1.7141e-06 - sparse_categorical_accuracy: 1.0000
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 1.7110e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4549 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 49/50
# 982/984 [============================>.] - ETA: 0s - loss: 7.8757e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 7.8616e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4551 - val_sparse_categorical_accuracy: 0.9339
# Learning rate:  1.0000000000000001e-07
# Epoch 50/50
# 982/984 [============================>.] - ETA: 0s - loss: 5.3906e-07 - sparse_categorical_accuracy: 1.0000
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.93443
# 984/984 [==============================] - 41s 42ms/step - loss: 5.3808e-07 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4552 - val_sparse_categorical_accuracy: 0.9339
