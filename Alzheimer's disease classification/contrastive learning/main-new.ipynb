# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras import layers
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import numpy as np
import losses
import time
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
trainDir = r"/home/trojan/Desktop/dimentia/dataset/data_2categ/data_PGGAN/train"
valDir = r"/home/trojan/Desktop/dimentia/dataset/data_2categ/data_PGGAN/validation"

IMG_SHAPE = 256
num_classes = 2
BS = 16
encoder_epochs = 40
classifier_epochs = 50
AUTO = tf.data.experimental.AUTOTUNE
dropout_rate = 0.2

# %%
def lr_schedule(epoch):

    lr = 1e-5 
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 40: # 120
        lr *= 1e-2
    elif epoch > 20: #80
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  trainDir,
  seed=7,
  image_size=(IMG_SHAPE, IMG_SHAPE),
  batch_size=BS,
  shuffle=True)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  valDir,
  seed=7,
  image_size=(IMG_SHAPE, IMG_SHAPE),
  batch_size=BS,
  shuffle=True)
# Out:
# Found 9740 files belonging to 2 classes.
# Found 115 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['AD', 'CN']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 256, 256, 3)
# (16,)

# %%
# Data Pipeline

@tf.function
def preprocess_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (IMG_SHAPE, IMG_SHAPE))
    image = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(image)
    return (image, label)

train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .prefetch(AUTO)
)


validation_ds = (
    val_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
# Model Bulding

# Reference: https://github.com/wangz10/contrastive_loss/blob/master/model.py
class UnitNormLayer(tf.keras.layers.Layer):
    '''Normalize vectors (euclidean norm) in batch to unit hypersphere.
    '''
    def __init__(self, **kwargs):
        super(UnitNormLayer, self).__init__()

    def call(self, input_tensor):
        norm = tf.norm(input_tensor, axis=1)
        return input_tensor / tf.reshape(norm, [-1, 1])

# %%
initializer = 'he_normal'
model = Sequential()

model.add(Conv2D(32, (5, 5), padding='same', input_shape = (256, 256, 3), kernel_initializer=initializer))
#model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(64, (5, 5), padding='same', kernel_initializer=initializer))
#model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer))
#model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer))
#model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer))
#model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Activation('relu'))

#model.add(Flatten())

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 512)         0
# =================================================================
# Total params: 1,606,848
# Trainable params: 1,604,864
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
# Encoder Network
def encoder_net():
    inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
    normalization_layer = UnitNormLayer()

    encoder = model
    encoder.trainable = True

    embeddings = encoder(inputs, training=True)
    embeddings = GlobalAveragePooling2D()(embeddings)
    norm_embeddings = normalization_layer(embeddings)

    encoder_network = Model(inputs, norm_embeddings)

    return encoder_network

# Projector Network
def projector_net():
    projector = tf.keras.models.Sequential([
        Dense(256, activation="relu"),
        UnitNormLayer()
])

    return projector

# %%
encoder_r = encoder_net()
projector_z = projector_net()

# %%
#Training encoder and the projector

optimizer = tf.keras.optimizers.Adam(lr=lr_schedule(0))

encoder_r = encoder_net()
projector_z = projector_net()

@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        r = encoder_r(images, training=True)
        z = projector_z(r, training=True)
        loss = losses.max_margin_contrastive_loss(z, labels)

    gradients = tape.gradient(loss, 
        encoder_r.trainable_variables + projector_z.trainable_variables)
    optimizer.apply_gradients(zip(gradients, 
        encoder_r.trainable_variables + projector_z.trainable_variables))

    return loss
# Out:
# Learning rate:  1e-05

# %%
EPOCHS = encoder_epochs
train_loss_results = []

epoch_time = 0
total_time = 0
for epoch in range(EPOCHS):
    start = time.time()
    epoch_loss_avg = tf.keras.metrics.Mean()

    for (images, labels) in train_ds:
        loss = train_step(images, labels)
        epoch_loss_avg.update_state(loss) 

    train_loss_results.append(epoch_loss_avg.result())
    
    print("Epoch: {} Loss: {:.3f}".format(epoch, epoch_loss_avg.result()))

    end = time.time()
    epoch_time = end - start
    total_time += epoch_time
    
    print(f"Epoch Time: {epoch_time}")
    print(f"Total Time: {total_time}")
    
with plt.xkcd():
    plt.plot(train_loss_results)
    plt.title("Supervised Contrastive Loss")
    plt.show()
# Out:
# Epoch: 0 Loss: 0.257
# Epoch Time: 33.41166853904724
# Total Time: 33.41166853904724
# Epoch: 1 Loss: 0.208
# Epoch Time: 29.916895151138306
# Total Time: 63.32856369018555
# Epoch: 2 Loss: 0.179
# Epoch Time: 30.326189756393433
# Total Time: 93.65475344657898
# Epoch: 3 Loss: 0.164
# Epoch Time: 30.34762978553772
# Total Time: 124.0023832321167
# Epoch: 4 Loss: 0.148
# Epoch Time: 30.171438932418823
# Total Time: 154.17382216453552
# Epoch: 5 Loss: 0.138
# Epoch Time: 30.450763463974
# Total Time: 184.62458562850952
# Epoch: 6 Loss: 0.126
# Epoch Time: 30.466772079467773
# Total Time: 215.0913577079773
# Epoch: 7 Loss: 0.120
# Epoch Time: 30.2517409324646
# Total Time: 245.3430986404419
# Epoch: 8 Loss: 0.109
# Epoch Time: 30.11361861228943
# Total Time: 275.4567172527313
# Epoch: 9 Loss: 0.101
# Epoch Time: 30.31726861000061
# Total Time: 305.77398586273193
# Epoch: 10 Loss: 0.095
# Epoch Time: 30.386118412017822
# Total Time: 336.16010427474976
# Epoch: 11 Loss: 0.088
# Epoch Time: 30.146743059158325
# Total Time: 366.3068473339081
# Epoch: 12 Loss: 0.084
# Epoch Time: 30.902665615081787
# Total Time: 397.20951294898987
# Epoch: 13 Loss: 0.077
# Epoch Time: 31.237295150756836
# Total Time: 428.4468080997467
# Epoch: 14 Loss: 0.073
# Epoch Time: 30.420150995254517
# Total Time: 458.8669590950012
# Epoch: 15 Loss: 0.069
# Epoch Time: 30.165778636932373
# Total Time: 489.0327377319336
# Epoch: 16 Loss: 0.062
# Epoch Time: 30.145633935928345
# Total Time: 519.1783716678619
# Epoch: 17 Loss: 0.062
# Epoch Time: 30.152899980545044
# Total Time: 549.331271648407
# Epoch: 18 Loss: 0.058
# Epoch Time: 30.2214298248291
# Total Time: 579.5527014732361
# Epoch: 19 Loss: 0.055
# Epoch Time: 30.139670372009277
# Total Time: 609.6923718452454
# Epoch: 20 Loss: 0.050
# Epoch Time: 30.150906562805176
# Total Time: 639.8432784080505
# Epoch: 21 Loss: 0.049
# Epoch Time: 30.231168746948242
# Total Time: 670.0744471549988
# Epoch: 22 Loss: 0.044
# Epoch Time: 30.19058585166931
# Total Time: 700.2650330066681
# Epoch: 23 Loss: 0.043
# Epoch Time: 30.23127245903015
# Total Time: 730.4963054656982
# Epoch: 24 Loss: 0.042
# Epoch Time: 30.11811113357544
# Total Time: 760.6144165992737
# Epoch: 25 Loss: 0.039
# Epoch Time: 30.300153732299805
# Total Time: 790.9145703315735
# Epoch: 26 Loss: 0.034
# Epoch Time: 30.213998079299927
# Total Time: 821.1285684108734
# Epoch: 27 Loss: 0.034
# Epoch Time: 30.21189045906067
# Total Time: 851.3404588699341
# Epoch: 28 Loss: 0.032
# Epoch Time: 30.130658864974976
# Total Time: 881.4711177349091
# Epoch: 29 Loss: 0.032
# Epoch Time: 30.17560601234436
# Total Time: 911.6467237472534
# Epoch: 30 Loss: 0.029
# Epoch Time: 30.482800245285034
# Total Time: 942.1295239925385
# Epoch: 31 Loss: 0.028
# Epoch Time: 30.1613130569458
# Total Time: 972.2908370494843
# Epoch: 32 Loss: 0.028
# Epoch Time: 30.175445556640625
# Total Time: 1002.4662826061249
# Epoch: 33 Loss: 0.026
# Epoch Time: 30.211416721343994
# Total Time: 1032.6776993274689
# Epoch: 34 Loss: 0.025
# Epoch Time: 30.42092776298523
# Total Time: 1063.098627090454
# Epoch: 35 Loss: 0.023
# Epoch Time: 30.179490327835083
# Total Time: 1093.2781174182892
# Epoch: 36 Loss: 0.023
# Epoch Time: 30.15664529800415
# Total Time: 1123.4347627162933
# Epoch: 37 Loss: 0.022
# Epoch Time: 30.23899483680725
# Total Time: 1153.6737575531006
# Epoch: 38 Loss: 0.021
# Epoch Time: 30.379494428634644
# Total Time: 1184.0532519817352
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# Epoch: 39 Loss: 0.020
# Epoch Time: 30.189027070999146
# Total Time: 1214.2422790527344

# %%
encoder_r.save('encoder_model.h5')
projector_z.save('projection_model.h5')

# %%
encoder_r = load_model('encoder_model.h5', custom_objects={'UnitNormLayer': UnitNormLayer}, compile=False)

# %%
# Supervised training

def supervised_model():
    inputs = Input((IMG_SHAPE, IMG_SHAPE, 3))
    encoder_r.trainable = False

    r = encoder_r(inputs, training=False)
    r = layers.Dense(256, activation="relu")(r)
    r = layers.Dropout(dropout_rate)(r)
    r = layers.Dense(128, activation="relu")(r)
    r = layers.Dropout(dropout_rate)(r)
    outputs = Dense(num_classes)(r)

    supervised_model = Model(inputs, outputs)

    return supervised_model

# %%
supervised_classifier = supervised_model()

supervised_classifier.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_schedule(0)),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])


checkpoint = ModelCheckpoint('best_model_contrastive.h5', monitor='val_sparse_categorical_accuracy', mode='max', verbose=1, save_best_only=True)
#es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5,
    #restore_best_weights=True, verbose=2)

lr_scheduler = LearningRateScheduler(lr_schedule)
    
supervised_classifier.fit(train_ds,
    validation_data=validation_ds,
    epochs=classifier_epochs,
    callbacks=[checkpoint, lr_scheduler])
# Out:
# Learning rate:  1e-05
# Learning rate:  1e-05
# Epoch 1/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.6853 - sparse_categorical_accuracy: 0.6124
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.55652, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.6853 - sparse_categorical_accuracy: 0.6125 - val_loss: 0.6886 - val_sparse_categorical_accuracy: 0.5565
# Learning rate:  1e-05
# Epoch 2/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.6684 - sparse_categorical_accuracy: 0.7272
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.55652 to 0.59130, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.6684 - sparse_categorical_accuracy: 0.7274 - val_loss: 0.6830 - val_sparse_categorical_accuracy: 0.5913
# Learning rate:  1e-05
# Epoch 3/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.6492 - sparse_categorical_accuracy: 0.7495
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.59130
# 609/609 [==============================] - 20s 32ms/step - loss: 0.6492 - sparse_categorical_accuracy: 0.7495 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.5913
# Learning rate:  1e-05
# Epoch 4/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.6250 - sparse_categorical_accuracy: 0.7780
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.59130
# 609/609 [==============================] - 20s 33ms/step - loss: 0.6249 - sparse_categorical_accuracy: 0.7782 - val_loss: 0.6710 - val_sparse_categorical_accuracy: 0.5826
# Learning rate:  1e-05
# Epoch 5/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.5933 - sparse_categorical_accuracy: 0.8136
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.59130
# 609/609 [==============================] - 20s 33ms/step - loss: 0.5933 - sparse_categorical_accuracy: 0.8139 - val_loss: 0.6641 - val_sparse_categorical_accuracy: 0.5913
# Learning rate:  1e-05
# Epoch 6/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.5550 - sparse_categorical_accuracy: 0.8530
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.59130 to 0.60000, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.5548 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.6543 - val_sparse_categorical_accuracy: 0.6000
# Learning rate:  1e-05
# Epoch 7/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.5099 - sparse_categorical_accuracy: 0.8905
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.60000 to 0.65217, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.5098 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.6429 - val_sparse_categorical_accuracy: 0.6522
# Learning rate:  1e-05
# Epoch 8/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.4585 - sparse_categorical_accuracy: 0.9330
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.65217 to 0.66957, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.4585 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.6308 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 9/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.4031 - sparse_categorical_accuracy: 0.9628
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.66957
# 609/609 [==============================] - 20s 32ms/step - loss: 0.4030 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.6235 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 10/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.3467 - sparse_categorical_accuracy: 0.9829
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.66957 to 0.69565, saving model to best_model_contrastive.h5
# 609/609 [==============================] - 20s 33ms/step - loss: 0.3466 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.6231 - val_sparse_categorical_accuracy: 0.6957
# Learning rate:  1e-05
# Epoch 11/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.2931 - sparse_categorical_accuracy: 0.9912
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.6134 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 12/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.2425 - sparse_categorical_accuracy: 0.9966
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.2424 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.6113 - val_sparse_categorical_accuracy: 0.6783
# Learning rate:  1e-05
# Epoch 13/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.2001 - sparse_categorical_accuracy: 0.9980
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.6293 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 14/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.1627 - sparse_categorical_accuracy: 0.9990
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.1627 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.6462 - val_sparse_categorical_accuracy: 0.6522
# Learning rate:  1e-05
# Epoch 15/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.1323 - sparse_categorical_accuracy: 0.9993
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 16/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.1065 - sparse_categorical_accuracy: 0.9993- ETA: 6s - loss: 0.1111 -
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.1064 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.6800 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1e-05
# Epoch 17/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0863 - sparse_categorical_accuracy: 0.9995
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.7128 - val_sparse_categorical_accuracy: 0.6609
# Learning rate:  1e-05
# Epoch 18/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0688 - sparse_categorical_accuracy: 0.9999- ETA: 0s - loss: 0.0689 - sparse_categorical_acc
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.7337 - val_sparse_categorical_accuracy: 0.6609
# Learning rate:  1e-05
# Epoch 19/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0557 - sparse_categorical_accuracy: 0.9997- ETA: 3s
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 32ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.7735 - val_sparse_categorical_accuracy: 0.6609
# Learning rate:  1e-05
# Epoch 20/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0452 - sparse_categorical_accuracy: 0.9998
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.7934 - val_sparse_categorical_accuracy: 0.6609
# Learning rate:  1e-05
# Epoch 21/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0363 - sparse_categorical_accuracy: 0.9999
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8541 - val_sparse_categorical_accuracy: 0.6609
# Learning rate:  1.0000000000000002e-06
# Epoch 22/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0323 - sparse_categorical_accuracy: 1.0000
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0323 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8147 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 23/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0316 - sparse_categorical_accuracy: 0.9999
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8223 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 24/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0310 - sparse_categorical_accuracy: 0.9999
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8268 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 25/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0296 - sparse_categorical_accuracy: 0.9998
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8316 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 26/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0287 - sparse_categorical_accuracy: 0.9999
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8327 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 27/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.0284 - sparse_categorical_accuracy: 0.9997
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0284 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.8384 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 28/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.0275 - sparse_categorical_accuracy: 0.9999
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8359 - val_sparse_categorical_accuracy: 0.6783
# Learning rate:  1.0000000000000002e-06
# Epoch 29/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0268 - sparse_categorical_accuracy: 0.9999
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8479 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 30/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0264 - sparse_categorical_accuracy: 0.9999
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8445 - val_sparse_categorical_accuracy: 0.6783
# Learning rate:  1.0000000000000002e-06
# Epoch 31/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0260 - sparse_categorical_accuracy: 1.0000
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 32ms/step - loss: 0.0259 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8588 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 32/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0248 - sparse_categorical_accuracy: 0.9999
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8620 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 33/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0245 - sparse_categorical_accuracy: 0.9998
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8658 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 34/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0237 - sparse_categorical_accuracy: 0.9998
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8724 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 35/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0230 - sparse_categorical_accuracy: 0.9999
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8797 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 36/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0228 - sparse_categorical_accuracy: 0.9999
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0227 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8860 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 37/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0216 - sparse_categorical_accuracy: 0.9999
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0215 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8865 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 38/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.0216 - sparse_categorical_accuracy: 0.9999
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8981 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 39/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0206 - sparse_categorical_accuracy: 0.9998
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8955 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 40/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0202 - sparse_categorical_accuracy: 0.9999
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9013 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000002e-06
# Epoch 41/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0198 - sparse_categorical_accuracy: 0.9998
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0198 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.9089 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 42/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0192 - sparse_categorical_accuracy: 0.9999
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9047 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 43/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0193 - sparse_categorical_accuracy: 0.9999
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9038 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 44/50
# 608/609 [============================>.] - ETA: 0s - loss: 0.0191 - sparse_categorical_accuracy: 0.9999
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9029 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 45/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0191 - sparse_categorical_accuracy: 0.9999- ETA: 0s - loss: 0.0191 - sparse_categorical_accu
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9024 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 46/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0193 - sparse_categorical_accuracy: 0.9998
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.9027 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 47/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0189 - sparse_categorical_accuracy: 0.9999
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9027 - val_sparse_categorical_accuracy: 0.6783
# Learning rate:  1.0000000000000001e-07
# Epoch 48/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0186 - sparse_categorical_accuracy: 0.9999
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 32ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9046 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 49/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0188 - sparse_categorical_accuracy: 0.9998- ETA
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.9055 - val_sparse_categorical_accuracy: 0.6696
# Learning rate:  1.0000000000000001e-07
# Epoch 50/50
# 607/609 [============================>.] - ETA: 0s - loss: 0.0184 - sparse_categorical_accuracy: 0.9999
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.69565
# 609/609 [==============================] - 20s 33ms/step - loss: 0.0183 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.9051 - val_sparse_categorical_accuracy: 0.6696
