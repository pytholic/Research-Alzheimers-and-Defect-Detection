# %%
import pandas as pd
import numpy as np

df = pd.read_csv('jehung_data/new_try/defected_boundary_new.csv')
j = np.asarray(df)

# %%
print (j)
# Out:
# [[ 18 172]
#  [ 18 173]
#  [ 18 174]
#  ...
#  [231 173]
#  [231 174]
#  [231 175]]

# %%
print(j[:,0])
# Out:
# [ 18  18  18 ... 231 231 231]

# %%
print(len(j))
# Out:
# 1233

# %%
import re
import pandas as pd
from PIL import Image, ImageDraw
import PIL
import matplotlib.pyplot as plt

width = 200 #350 #293
height = 240 #400 #193

    
im = Image.new('RGB', (width, height), (128, 128, 128))
draw = ImageDraw.Draw(im)

draw.rectangle((0, height, width, 0), fill=(255, 255, 255), outline=(0, 0, 0)) # white, black

for x,y in j:
    print(x,y)

    #im.show()
#draw.ellipse((100, 100, 150, 200), fill=(255, 0, 0), outline=(0, 0, 0))
#draw.rectangle((200, 100, 300, 200), fill=(0, 192, 192), outline=(255, 255, 255))
#draw.line((350, 200, 450, 100), fill=(255, 255, 0), width=10)

    draw.point((y,x),fill=(255, 0, 0))
# Out:
# 18 172
# 18 173
# 18 174
# 18 175
# 18 180
# 19 24
# 19 25
# 19 26
# 19 27
# 19 28
# 19 110
# 19 111
# 19 146
# 19 147
# 19 148
# 19 149
# 19 150
# 19 151
# 19 169
# 19 170
# 19 176
# 19 177
# 19 178
# 19 180
# 20 23
# 20 24
# 20 28
# 20 47
# 20 48
# 20 49
# 20 50
# 20 51
# 20 52
# 20 53
# 20 54
# 20 55
# 20 56
# 20 57
# 20 109
# 20 110
# 20 112
# 20 113
# 20 146
# 20 151
# 20 152
# 20 169
# 20 180
# 21 23
# 21 28
# 21 47
# 21 57
# 21 58
# 21 89
# 21 106
# 21 107
# 21 108
# 21 110
# 21 113
# 21 114
# 21 115
# 21 116
# 21 117
# 21 147
# 21 152
# 21 169
# 21 180
# 22 23
# 22 29
# 22 47
# 22 58
# 22 85
# 22 86
# 22 87
# 22 88
# 22 89
# 22 90
# 22 106
# 22 118
# 22 119
# 22 147
# 22 152
# 22 170
# 22 180
# 23 23
# 23 28
# 23 46
# 23 58
# 23 83
# 23 84
# 23 85
# 23 89
# 23 106
# 23 120
# 23 147
# 23 152
# 23 170
# 23 180
# 24 23
# 24 28
# 24 46
# 24 58
# 24 83
# 24 89
# 24 106
# 24 120
# 24 148
# 24 151
# 24 170
# 24 180
# 25 24
# 25 28
# 25 46
# 25 58
# 25 83
# 25 89
# 25 106
# 25 120
# ...

# %%
fig = plt.figure(figsize=(20,20))
ax = im
plt.imshow(ax, origin = 'lower')
#plt.axis('off')
plt.show()
fig.savefig('jehung_data/new_try/replotted_boundary.png', bbox_inches='tight')
plt.close(fig)

# %%
fig = plt.figure(figsize=(20,20))
ax = im
plt.imshow(ax, origin = 'lower')
plt.axis('off')
plt.xticks([]), plt.yticks([])
plt.show()
fig.savefig('composite patch/new_try/replotted_boundary2.png', bbox_inches='tight')
plt.close(fig)
