# %%
import numpy as np
import cv2 
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter

# %matplotlib inline


#origin issue is here, it is readin image wrong

image = cv2.imread('composite patch/new_try_tuning/defected_area.png') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) # convert to HSV
image = cv2.flip(image,0) #to fix the inverted origin issue

fig = plt.figure(figsize=(20,20))
ax = image
plt.imshow(ax, origin = 'lower')
#plt.axis('off')
plt.show()

#figure_size = 9 #the dimension of the x and y axis of the kernal.

ksize = (5, 5)
new_image = cv2.blur(image,ksize)
#new_image = cv2.blur(image,(figure_size, figure_size))
plt.figure(figsize=(15,10))

plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_HSV2RGB)),plt.title('Original')
#plt.xticks([]), plt.yticks([])

plt.subplot(122), plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB)),plt.title('Mean filter')
#plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8dcee9b2b7e5> in <module>
#      10
#      11 image = cv2.imread('D:/LAB Project Data/1D signal/boundary/composite patch/CV2 imshow attempt/defected_area_new.png') # reads the image
# ---> 12 image = cv2.cvtColor(image) # convert to HSV
#      13 image = cv2.flip(image,0) #to fix the inverted origin issue
#      14
#
# TypeError: cvtColor() missing required argument 'code' (pos 2)

# %%
plt.figure(figsize=(7,7))
#plt.figure(figsize=None)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB), origin='lower')
#plt.xticks([]), plt.yticks([])
#plt.axis('off')
#plt.savefig('composite patch/new_try/mean_filter_new.png', bbox_inches='tight')
plt.show()

# %%
#for further coordinate matching

#plt.figure(figsize=(4.25,4.25)) #for jehung data
plt.figure(figsize=(7,7))
#plt.figure(figsize=None)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB), origin='lower')
plt.xticks([]), plt.yticks([])
plt.axis('off')
plt.savefig('composite patch/new_try_tuning/mean_filter.png', bbox_inches='tight')
plt.show()

# %%
#To check origin issue


plt.figure(figsize=(7.50,7.15))
#plt.figure(figsize=None)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB), origin='lower')
#plt.xticks([]), plt.yticks([])
#plt.axis('off')
plt.show()

# %%
'D:/LAB Project Data/1D signal/boundary/composite patch/CV2 imshow attempt/defected_area_new.png'

import numpy as np
import cv2 
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter

# %matplotlib inline


#origin issue is here, it is readin image wrong

image = cv2.imread('D:/LAB Project Data/1D signal/boundary/composite patch/CV2 imshow attempt/defected_area_new.png') # reads the image
#image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) # convert to HSV
image = cv2.flip(image,0) #to fix the inverted origin issue

ksize = (5, 5)
new_image = cv2.blur(image,ksize)

cv2.imshow("blurred", new_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-26fa43661665> in <module>
#      19
#      20 cv2.imshow("blurred", new_image)
# ---> 21 image.imshow()
#      22 cv2.waitKey(0)
#      23 cv2.destroyAllWindows()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imshow'
