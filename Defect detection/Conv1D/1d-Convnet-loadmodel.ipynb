# %% [markdown]
# # Training

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/trojan/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from sklearn.model_selection import train_test_split
from keras.models import load_model 
import pickle

pickle_in = open('/home/trojan/Desktop/defect-detection/conv1d/training data/X.pickle', 'rb')
X = pickle.load(pickle_in)

pickle_in = open('/home/trojan/Desktop/defect-detection/conv1d/training data/y.pickle', 'rb')
y = pickle.load(pickle_in)

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(X, y, test_size=0.15, shuffle= True)

model = tf.keras.models.load_model("1dconvnet_model.h5")
model.load_weights ("1dconvnet_weights.h5")
# Out:
# WARNING:tensorflow:From /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/trojan/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Evaluation on split data

# %%
# evaluate model
model.evaluate(x_valid, y_valid, batch_size=1, verbose=1)
# Out:
# 3150/3150 [==============================] - 9s 3ms/sample - loss: 2.4715e-14 - acc: 1.0000
# [2.4714803391786935e-14, 1.0]

# %%
pred = model.predict(x_valid, verbose = 1)
# Out:
# 3150/3150 [==============================] - 0s 139us/sample

# %%
from keras.models import load_model 
model.save("1dconvnet_model.h5")
model.save_weights("1dconvnet_weights.h5")
# Out:
# Using TensorFlow backend.

# %%
import numpy as np

labels =  ['defected', 'nodefect']
 
indices = np.round(model.predict(x_valid),1)

# %%
import pandas as pd
# Get classes by np.round
# Get filenames (set shuffle=false in generator is important)
#filenames=test_generator.filenames

y = [labels[int(i[0])] for i in indices]
results=pd.DataFrame({"prediction": pred [:,0],
                          "class_index": indices[:,0],
                          "class_name": y })

results.to_csv("/home/trojan/Desktop/defect-detection/conv1d/results_valid.csv",index=False)

# %% [markdown]
# # Evaluation on new test data

# %%
#prediction is fine

import pandas as pd
import numpy as np
import os
import glob

path = '/home/trojan/Desktop/defect-detection/conv1d/test data 2'
os.chdir (path)

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

for test_csv in all_filenames:
    test_csv =pd.read_csv(test_csv)
    series = np.asarray(test_csv)
    series = np.array(series).reshape(-1, 499, 1)
#test_image = test_image.astype('float32')

    pred=model.predict(series, verbose=1)
    indices = np.round(pred[:,0])
    print (indices)
#labels =  ['defected', 'nodefect']

#indices2 = np.argmax(model.predict(test_csv),1)
                     
#print([labels[x] for x in indices2])
# Out:
# 1/1 [==============================] - 0s 886us/sample
# [0.]
# 1/1 [==============================] - 0s 854us/sample
# [0.]
# 1/1 [==============================] - 0s 829us/sample
# [0.]
# 1/1 [==============================] - 0s 738us/sample
# [0.]
# 1/1 [==============================] - 0s 1ms/sample
# [0.]

# %%
#on 222 test samples

pickle_in = open('/home/trojan/Desktop/defect-detection/conv1d/test data/X_test2.pickle', 'rb')
X_test = pickle.load(pickle_in)

pickle_in = open('/home/trojan/Desktop/defect-detection/conv1d/test data/y_test2.pickle', 'rb')
y_test = pickle.load(pickle_in)

model.evaluate(X_test, y_test, batch_size=1, verbose=1)
# Out:
# 222/222 [==============================] - 0s 2ms/sample - loss: 0.0032 - acc: 0.9955
# [0.003173482170211085, 0.9954955]

# %%
pickle_in = open('/home/trojan/Desktop/defect-detection/conv1d/test data/X_test.pickle', 'rb')
X_test = pickle.load(pickle_in)

pred = model.predict(X_test, verbose = 1)
# Out:
# 222/222 [==============================] - 0s 204us/sample

# %%
import numpy as np
import pandas as pd

labels =  ['defected', 'nodefect']
 
indices = np.round(model.predict(X_test),0)
#preds_cls_idx = pred.argmax(axis=-1)

for i in indices:
    y = (labels[int(i[0])])
    print (y)

    '''results=pd.DataFrame({"prediction": pred [:,0],
                          "class_index": indices[:,0],
                          "class_name":  y })

results.to_csv("/home/trojan/Desktop/defect-detection/conv1d/results222_test.csv",index=False)'''
# Out:
# nodefect
# defected
# nodefect
# nodefect
# nodefect
# defected
# defected
# defected
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# nodefect
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# defected
# defected
# defected
# defected
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# defected
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# defected
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# defected
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# defected
# defected
# defected
# nodefect
# defected
# defected
# nodefect
# nodefect
# defected
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# defected
# defected
# defected
# nodefect
# defected
# nodefect
# nodefect
# defected
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# defected
# defected
# nodefect
# nodefect
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# defected
# defected
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# defected
# defected
# defected
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# defected
# defected
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# nodefect
# defected
# nodefect
# nodefect
# defected
# nodefect
# defected
# defected
# nodefect
# defected
# defected
# nodefect
# defected

# %%
import pandas as pd
# Get classes by np.round
# Get filenames (set shuffle=false in generator is important)
#filenames=test_generator.filenames
    
#for f in all_filenames:

y = [labels[int(i[0])] for i in indices]
#y = [labels[x] for x in preds_cls_idx]
results=pd.DataFrame({"prediction": pred [:,0],
                          "class_index": indices[:,0],
                          "class_name":  y })

results.to_csv("/home/trojan/Desktop/defect-detection/conv1d/results222_test.csv",index=False)

# %%
import pandas as pd
import numpy as np
import os
import glob
import csv

path = '/home/trojan/Desktop/defect-detection/conv1d/test data2'
os.chdir (path)

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

results = pd.DataFrame()
for test_csv in all_filenames:
    df =pd.read_csv(test_csv)
    series = np.asarray(df)
    series = np.array(series).reshape(-1, 499, 1)
#test_image = test_image.astype('float32')

    pred=model.predict(series, verbose=1)
    indices = np.round(pred)
    print (indices)
    labels =  ['defected', 'nodefect']

    ''''for i in indices:
        y = (labels[int(i)])
        print (y)'''
    y = [labels[int(i)] for i in indices]
    print (y)
    print (test_csv)
    #M.append(test_csv)

#print (M)
    df=pd.DataFrame({"file": test_csv,
                          "prediction": pred [:,0],
                          "class_index": indices [:,0],
                          "class_name":  y })
    
    results = results.append(df)
    
        
results.to_csv("/home/trojan/Desktop/defect-detection/conv1d/results2222_test.csv",index=False)
# Out:
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1261).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1271).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1042).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1033).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1286).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1031).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1266).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1277).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1012).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1026).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1257).csv
# 1/1 [==============================] - 0s 982us/sample
# [[1.]]
# ['nodefect']
# point(1511,1258).csv
# 1/1 [==============================] - 0s 952us/sample
# [[1.]]
# ['nodefect']
# point(1510,1285).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1296).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1276).csv
# 1/1 [==============================] - 0s 892us/sample
# [[0.]]
# ['defected']
# point(1550,1008).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1032).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1298).csv
# 1/1 [==============================] - 0s 912us/sample
# [[0.]]
# ['defected']
# point(1551,1025).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1265).csv
# 1/1 [==============================] - 0s 981us/sample
# [[0.]]
# ['defected']
# point(1551,1046).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1298).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1033).csv
# 1/1 [==============================] - 0s 941us/sample
# [[0.]]
# ['defected']
# point(1550,1013).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1284).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1293).csv
# 1/1 [==============================] - 0s 949us/sample
# [[0.]]
# ['defected']
# point(1550,1055).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1301).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1256).csv
# 1/1 [==============================] - 0s 983us/sample
# [[1.]]
# ['nodefect']
# point(1511,1267).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1281).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1282).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1021).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1040).csv
# 1/1 [==============================] - 0s 943us/sample
# [[0.]]
# ['defected']
# point(1550,1051).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1029).csv
# 1/1 [==============================] - 0s 988us/sample
# [[0.]]
# ['defected']
# point(1551,1011).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1030).csv
# 1/1 [==============================] - 0s 975us/sample
# [[0.]]
# ['defected']
# point(1551,1055).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1007).csv
# 1/1 [==============================] - 0s 921us/sample
# [[1.]]
# ['nodefect']
# point(1510,1269).csv
# 1/1 [==============================] - 0s 992us/sample
# [[0.]]
# ['defected']
# point(1551,1042).csv
# 1/1 [==============================] - 0s 928us/sample
# [[0.]]
# ['defected']
# point(1551,1054).csv
# 1/1 [==============================] - 0s 1000us/sample
# [[0.]]
# ['defected']
# point(1551,1034).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1016).csv
# 1/1 [==============================] - 0s 976us/sample
# [[0.]]
# ['defected']
# point(1549,1051).csv
# 1/1 [==============================] - 0s 966us/sample
# [[0.]]
# ['defected']
# point(1550,1023).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1010).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1009).csv
# 1/1 [==============================] - 0s 996us/sample
# [[0.]]
# ['defected']
# point(1550,1019).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1044).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1051).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1278).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1289).csv
# 1/1 [==============================] - 0s 988us/sample
# [[0.]]
# ['defected']
# point(1550,1035).csv
# 1/1 [==============================] - 0s 917us/sample
# [[1.]]
# ['nodefect']
# point(1511,1295).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1289).csv
# 1/1 [==============================] - 0s 981us/sample
# [[1.]]
# ['nodefect']
# point(1511,1253).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1300).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1034).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1272).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1009).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1041).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1028).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1285).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1018).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1288).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1284).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1262).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1301).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1010).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1297).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1293).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1030).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1297).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1255).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1299).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1290).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1035).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1254).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1294).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1299).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1270).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1027).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1263).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1275).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1017).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1013).csv
# 1/1 [==============================] - 0s 986us/sample
# [[1.]]
# ['nodefect']
# point(1510,1297).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1295).csv
# 1/1 [==============================] - 0s 999us/sample
# [[1.]]
# ['nodefect']
# point(1511,1275).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1264).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1262).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1291).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1007).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1294).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1292).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1279).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1268).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1258).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1050).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1054).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1279).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1260).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1255).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1031).csv
# 1/1 [==============================] - 0s 984us/sample
# [[1.]]
# ['nodefect']
# point(1510,1265).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1044).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1014).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1023).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1273).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1038).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1045).csv
# 1/1 [==============================] - 0s 983us/sample
# [[1.]]
# ['nodefect']
# point(1510,1257).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1048).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1291).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1011).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1043).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1283).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1053).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1270).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1049).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1053).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1282).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1022).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1006).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1290).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1016).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1277).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1299).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1038).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1264).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1012).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1283).csv
# 1/1 [==============================] - 0s 969us/sample
# [[1.]]
# ['nodefect']
# point(1510,1301).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1046).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1300).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1055).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1292).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1050).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1274).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1272).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1281).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1028).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1039).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1027).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1008).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1271).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1050).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1019).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1036).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1018).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1032).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1280).csv
# 1/1 [==============================] - 0s 959us/sample
# [[1.]]
# ['nodefect']
# point(1510,1261).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1295).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1287).csv
# 1/1 [==============================] - 0s 999us/sample
# [[1.]]
# ['nodefect']
# point(1511,1263).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1014).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1266).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1296).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1288).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1300).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1296).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1267).csv
# 1/1 [==============================] - 0s 905us/sample
# [[0.]]
# ['defected']
# point(1550,1024).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1022).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1259).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1037).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1252).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1260).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1268).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1040).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1047).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1280).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1017).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1045).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1269).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1054).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1029).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1276).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1287).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1049).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1020).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1273).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1024).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1037).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1253).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1298).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1251).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1251).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1551,1006).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1049).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1025).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1036).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1293).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1015).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1041).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1039).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1021).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1020).csv
# 1/1 [==============================] - 0s 1000us/sample
# [[0.]]
# ['defected']
# point(1551,1043).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1048).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1278).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1048).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1259).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1274).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1026).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1015).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1053).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1286).csv
# 1/1 [==============================] - 0s 933us/sample
# [[1.]]
# ['nodefect']
# point(1510,1252).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1254).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1047).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1256).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1294).csv

# %%
#for just defected

import pandas as pd
import numpy as np
import os
import glob
import csv

path = '/home/trojan/Desktop/defect-detection/conv1d/test data2'
os.chdir (path)

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

results = pd.DataFrame()
for test_csv in all_filenames:
    df =pd.read_csv(test_csv)
    series = np.asarray(df)
    series = np.array(series).reshape(-1, 499, 1)
#test_image = test_image.astype('float32')

    pred=model.predict(series, verbose=1)
    indices = np.round(pred)
    print (indices)
    labels =  ['defected', 'nodefect']

    ''''for i in indices:
        y = (labels[int(i)])
        print (y)'''
    y = [labels[int(i)] for i in indices]
    print (y)
    print (test_csv)
    #M.append(test_csv)

#print (M)
    df=pd.DataFrame({"file": test_csv,
                          "prediction": pred [:,0],
                          "class_index": indices [:,0],
                          "class_name":  y })
    
    results = results.append(df)
    results = results[results.class_name != 'nodefect']
        
results.to_csv("/home/trojan/Desktop/defect-detection/conv1d/results_test_just-defected.csv",index=False)
# Out:
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1261).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1271).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1550,1042).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1033).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1286).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1550,1031).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1266).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1277).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1012).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1026).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1257).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1258).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1285).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1296).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1276).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1008).csv
# 1/1 [==============================] - 0s 964us/sample
# [[0.]]
# ['defected']
# point(1550,1032).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1298).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1025).csv
# 1/1 [==============================] - 0s 931us/sample
# [[1.]]
# ['nodefect']
# point(1511,1265).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1046).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1298).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1033).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1013).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1284).csv
# 1/1 [==============================] - 0s 938us/sample
# [[1.]]
# ['nodefect']
# point(1510,1293).csv
# 1/1 [==============================] - 0s 973us/sample
# [[0.]]
# ['defected']
# point(1550,1055).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1301).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1256).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1267).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1281).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1282).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1021).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1040).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1051).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[0.]]
# ['defected']
# point(1550,1029).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1011).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1030).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1055).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1007).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1269).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1042).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1054).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1551,1034).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1550,1016).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1051).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1023).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1010).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1009).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[0.]]
# ['defected']
# point(1550,1019).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1044).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1051).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1278).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1289).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1035).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1295).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1289).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1253).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1300).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1034).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1272).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1009).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1041).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1028).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1285).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1018).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1288).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1284).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1262).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1301).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[0.]]
# ['defected']
# point(1551,1010).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1297).csv
# 1/1 [==============================] - 0s 981us/sample
# [[1.]]
# ['nodefect']
# point(1511,1293).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1030).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1297).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1255).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1299).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1290).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1035).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1254).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1294).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1299).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1270).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1027).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1263).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1275).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1017).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1013).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1297).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1295).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1275).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1264).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1262).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1291).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1007).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1294).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1292).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1279).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1268).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1258).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1050).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1054).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1279).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1260).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1255).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1031).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1265).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1044).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1014).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1023).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1273).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1038).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1045).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1257).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1048).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1549,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1056).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1291).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1011).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1043).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1283).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1053).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1270).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1049).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1053).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1282).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1022).csv
# 1/1 [==============================] - 0s 970us/sample
# [[0.]]
# ['defected']
# point(1550,1006).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1290).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1016).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1277).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1299).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1038).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1264).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1012).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1283).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1301).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1046).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1300).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1549,1055).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1292).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1050).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1274).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1272).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1281).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1028).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1039).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1027).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1008).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1271).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1050).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1019).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1036).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1018).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1032).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1280).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1261).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1295).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1287).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1263).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1014).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1266).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1296).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1288).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1300).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1296).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1267).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1024).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1022).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1259).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1037).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1252).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1260).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1268).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1040).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1047).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1280).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1017).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1550,1045).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1269).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1549,1054).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1029).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1276).csv
# 1/1 [==============================] - 0s 3ms/sample
# [[0.]]
# ['defected']
# point(1549,1052).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1287).csv
# 1/1 [==============================] - 0s 4ms/sample
# [[0.]]
# ['defected']
# point(1549,1049).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1020).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1273).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1024).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1037).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1253).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1298).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1251).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1251).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1006).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1049).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1025).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1036).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1293).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1015).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1550,1041).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1039).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1021).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1020).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[0.]]
# ['defected']
# point(1551,1043).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1549,1048).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1278).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1048).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1259).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1274).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1026).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1015).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1550,1053).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1286).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1252).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1510,1254).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[0.]]
# ['defected']
# point(1551,1047).csv
# 1/1 [==============================] - 0s 1ms/sample
# [[1.]]
# ['nodefect']
# point(1511,1256).csv
# 1/1 [==============================] - 0s 2ms/sample
# [[1.]]
# ['nodefect']
# point(1509,1294).csv

# %% [markdown]
# # with timeseriesgen

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.python.keras.utils.data_utils import Sequence
from keras.utils import Sequence

DATADIR = "/home/trojan/Desktop/defect-detection/conv1d/test data2"
#CATEGORIES = ["defected", "nodefect"]




#for category in CATEGORIES:
    #path = os.path.join(DATADIR, category)
    #for csv in os.listdir(path):
os.chdir (DATADIR)

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
for f in all_filenames:
    df = pd.read_csv(f)
    #print (df)
    series = np.array(df)
    targets = np.array(df)
    test_generator = TimeseriesGenerator(series, targets, length = 499,
                               batch_size=1, start_index = 0, end_index = 499)

print('Samples: %d' % len(test_generator))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-2b323a61b369> in <module>
#      21     series = np.array(df)
#      22     targets = np.array(df)
# ---> 23     while (series):
#      24         test_generator = TimeseriesGenerator(series, targets, length = 499,
#      25                                batch_size=1, start_index = 0, end_index = 499)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.python.keras.utils.data_utils import Sequence
from keras.utils import Sequence
    
test_generator = TimeseriesGenerator(X_test, X_test, length = len(test_generator),
                               batch_size=1, start_index = 0, end_index = 499)

print('Samples: %d' % len(test_generator))
# Out:
# Samples: 1

# %%
#STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
#test_generator.reset()

pred=model.predict_generator(test_generator,
verbose=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-ede977b68022> in <module>
#       3
#       4 pred=model.predict_generator(test_generator,
# ----> 5 verbose=1)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1553         use_multiprocessing=use_multiprocessing,
#    1554         verbose=verbose,
# -> 1555         callbacks=callbacks)
#    1556
#    1557   def _validate_compile_param_for_distribution_strategy(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     218     step = 0
#     219     while step < target_steps:
# --> 220       batch_data = _get_next_batch(generator, mode)
#     221       if batch_data is None:
#     222         if is_dataset:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in _get_next_batch(generator, mode)
#     360   """Retrieves the next batch of input data."""
#     361   try:
# --> 362     generator_output = next(generator)
#     363   except (StopIteration, errors.OutOfRangeError):
#     364     return None
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     783     except Exception:  # pylint: disable=broad-except
#     784       self.stop()
# --> 785       six.reraise(*sys.exc_info())
#     786
#     787
#
# ~/.local/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     777     try:
#     778       while self.is_running():
# --> 779         inputs = self.queue.get(block=True).get()
#     780         self.queue.task_done()
#     781         if inputs is not None:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /usr/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in get_index(uid, i)
#     569       The value at index `i`.
#     570   """
# --> 571   return _SHARED_SEQUENCES[uid][i]
#     572
#     573
#
# ~/.local/lib/python3.6/site-packages/keras_preprocessing/sequence.py in __getitem__(self, index)
#     370         samples = np.array([self.data[row - self.length:row:self.sampling_rate]
#     371                             for row in rows])
# --> 372         targets = np.array([self.targets[row] for row in rows])
#     373
#     374         if self.reverse:
#
# ~/.local/lib/python3.6/site-packages/keras_preprocessing/sequence.py in <listcomp>(.0)
#     370         samples = np.array([self.data[row - self.length:row:self.sampling_rate]
#     371                             for row in rows])
# --> 372         targets = np.array([self.targets[row] for row in rows])
#     373
#     374         if self.reverse:
#
# IndexError: index 499 is out of bounds for axis 0 with size 222
